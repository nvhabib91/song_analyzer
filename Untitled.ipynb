# %%
from sklearn import tree
import pandas as pd
import os

# %%
df = pd.read_csv("analysis_data_sources\CAL10K_with_Spotify_WithFeatures.tab", sep='\t')

# %%
df.head()
# Out:
#    Unnamed: 0                                     Song               Genre  \
# 0           0  Luther Vandross - If Only For One Night  adult contemporary
# 1           1                Duran Duran - Come Undone  adult contemporary
# 2           2                  Tears For Fears - Shout  adult contemporary
# 3           3             Marvin Gaye - Sexual healing  adult contemporary
# 4           4           Jack Johnson - Better Together  adult contemporary
#
#                Spotify_ID  danceability  energy  key  loudness  mode  \
# 0  2p4WnpR3H16ywshkL2Fp1n         0.498   0.249  9.0   -13.619   0.0
# 1  0yfNXxlyXdmP0ue1iJijx1         0.542   0.793  8.0    -8.203   1.0
# 2  2gQaQUhDCNGfBVXTvxAmXQ         0.511   0.942  0.0   -10.407   1.0
# 3  3VZmChrnVW8JK6ano4gSED         0.805   0.601  0.0    -9.700   0.0
# 4  4VywXu6umkIQ2OS0m1I79y         0.868   0.347  5.0    -9.529   1.0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
target = df
